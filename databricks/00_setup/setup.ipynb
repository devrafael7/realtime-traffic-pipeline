-- %%
CREATE CATALOG IF NOT EXISTS traffic_catalog

-- %%
CREATE SCHEMA IF NOT EXISTS traffic_catalog.bronze;
CREATE SCHEMA IF NOT EXISTS traffic_catalog.silver;
CREATE SCHEMA IF NOT EXISTS traffic_catalog.gold;

-- %%
CREATE SCHEMA IF NOT EXISTS traffic_catalog.traffic;
CREATE VOLUME IF NOT EXISTS traffic_catalog.traffic.checkpoints;
